# %%
#this part is used for using all of the data as a feature set
import numpy as np
import pandas as pd
#Fetching the csv file
carDf = pd.read_csv("/home/tulug/Desktop/CS552HW2/car-pricing-data.csv")
carDf
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
#Checking out the data
#Head of the Data
carDf.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
#Tail of the data
carDf.tail()
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#       max_power  seats
# 8123  82.85 bhp    5.0
# 8124    110 bhp    5.0
# 8125   73.9 bhp    5.0
# ...

# %%
#Info of the data
carDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 762.1+ KB

# %%
# #of the missing rows
carDf.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# seats            221
# dtype: int64

# %%
#row and column number of data
carDf.shape
# Out:
# (8128, 12)

# %%
#correlation of data
carDf.corr()
# Out:
#                    year  selling_price  km_driven     seats
# year           1.000000       0.414092  -0.418006 -0.009144
# selling_price  0.414092       1.000000  -0.225534  0.041358
# km_driven     -0.418006      -0.225534   1.000000  0.227336
# seats         -0.009144       0.041358   0.227336  1.000000

# %%
#features of data
columnNames = list(carDf.columns.values)
columnNames
# Out:
# ['name',
#  'year',
#  'selling_price',
#  'km_driven',
#  'fuel',
#  'seller_type',
#  'transmission',
#  'owner',
#  'mileage',
#  'engine',
#  'max_power',
#  'seats']

# %%
#dependent feature
carDf["selling_price"]
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 8128, dtype: int64

# %%
#independent features
columnNames.pop(2) # second item is dependent variable so it is removed from the list
carDf[columnNames]
# Out:
#                               name  year  km_driven    fuel seller_type  \
# 0           Maruti Swift Dzire VDI  2014     145500  Diesel  Individual
# 1     Skoda Rapid 1.5 TDI Ambition  2014     120000  Diesel  Individual
# 2         Honda City 2017-2020 EXi  2006     140000  Petrol  Individual
# 3        Hyundai i20 Sportz Diesel  2010     127000  Diesel  Individual
# 4           Maruti Swift VXI BSIII  2007     120000  Petrol  Individual
# ...                            ...   ...        ...     ...         ...
# 8123             Hyundai i20 Magna  2013     110000  Petrol  Individual
# 8124         Hyundai Verna CRDi SX  2007     119000  Diesel  Individual
# 8125        Maruti Swift Dzire ZDi  2009     120000  Diesel  Individual
# 8126               Tata Indigo CR4  2013      25000  Diesel  Individual
# 8127               Tata Indigo CR4  2013      25000  Diesel  Individual
#
#      transmission                 owner     mileage   engine   max_power  \
# ...

# %%
#Visualizing the data for each dependent feature with independent feature
carDf[["name","selling_price"]]
# Out:
#                               name  selling_price
# 0           Maruti Swift Dzire VDI         450000
# 1     Skoda Rapid 1.5 TDI Ambition         370000
# 2         Honda City 2017-2020 EXi         158000
# 3        Hyundai i20 Sportz Diesel         225000
# 4           Maruti Swift VXI BSIII         130000
# ...                            ...            ...
# 8123             Hyundai i20 Magna         320000
# 8124         Hyundai Verna CRDi SX         135000
# 8125        Maruti Swift Dzire ZDi         382000
# 8126               Tata Indigo CR4         290000
# 8127               Tata Indigo CR4         290000
#
# [8128 rows x 2 columns]

# %%
#Graphing the data for each dependent feature with independent feature
plt.subplot(1,2,1)
plt.scatter(carDf['name'], carDf['selling_price'])
plt.ylabel('Feature of Selling Price')
plt.xlabel('Feature of Name')
plt.show()

# %%
carDf[["year","selling_price"]]
# Out:
#       year  selling_price
# 0     2014         450000
# 1     2014         370000
# 2     2006         158000
# 3     2010         225000
# 4     2007         130000
# ...    ...            ...
# 8123  2013         320000
# 8124  2007         135000
# 8125  2009         382000
# 8126  2013         290000
# 8127  2013         290000
#
# [8128 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.scatter(carDf['year'], carDf['selling_price'])
plt.ylabel('Feature of Selling Price')
plt.xlabel('Feature of Year')
plt.show()

# %%
carDf[["seller_type","selling_price"]]
# Out:
#      seller_type  selling_price
# 0     Individual         450000
# 1     Individual         370000
# 2     Individual         158000
# 3     Individual         225000
# 4     Individual         130000
# ...          ...            ...
# 8123  Individual         320000
# 8124  Individual         135000
# 8125  Individual         382000
# 8126  Individual         290000
# 8127  Individual         290000
#
# [8128 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.scatter(carDf['seller_type'], carDf['selling_price'])
plt.ylabel('Feature of Selling Price')
plt.xlabel('Feature of Seller Type')
plt.show()

# %%
carDf[["transmission","selling_price"]]
# Out:
#      transmission  selling_price
# 0          Manual         450000
# 1          Manual         370000
# 2          Manual         158000
# 3          Manual         225000
# 4          Manual         130000
# ...           ...            ...
# 8123       Manual         320000
# 8124       Manual         135000
# 8125       Manual         382000
# 8126       Manual         290000
# 8127       Manual         290000
#
# [8128 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.scatter(carDf['transmission'], carDf['selling_price'])
plt.ylabel('Feature of Selling Price')
plt.xlabel('Feature of Transmission')
plt.show()

# %%
carDf[["owner","selling_price"]]
# Out:
#                      owner  selling_price
# 0              First Owner         450000
# 1             Second Owner         370000
# 2              Third Owner         158000
# 3              First Owner         225000
# 4              First Owner         130000
# ...                    ...            ...
# 8123           First Owner         320000
# 8124  Fourth & Above Owner         135000
# 8125           First Owner         382000
# 8126           First Owner         290000
# 8127           First Owner         290000
#
# [8128 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.scatter(carDf['owner'], carDf['selling_price'])
plt.ylabel('Feature of Selling Price')
plt.xlabel('Feature of Owner')
plt.show()

# %%
carDf[["mileage","selling_price"]]
# Out:
#          mileage  selling_price
# 0      23.4 kmpl         450000
# 1     21.14 kmpl         370000
# 2      17.7 kmpl         158000
# 3      23.0 kmpl         225000
# 4      16.1 kmpl         130000
# ...          ...            ...
# 8123   18.5 kmpl         320000
# 8124   16.8 kmpl         135000
# 8125   19.3 kmpl         382000
# 8126  23.57 kmpl         290000
# 8127  23.57 kmpl         290000
#
# [8128 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.scatter(carDf['mileage'].astype(str), carDf['selling_price'])
plt.ylabel('Feature of Selling Price')
plt.xlabel('Feature of Mileage')
plt.show()

# %%
carDf[["engine","selling_price"]]
# Out:
#        engine  selling_price
# 0     1248 CC         450000
# 1     1498 CC         370000
# 2     1497 CC         158000
# 3     1396 CC         225000
# 4     1298 CC         130000
# ...       ...            ...
# 8123  1197 CC         320000
# 8124  1493 CC         135000
# 8125  1248 CC         382000
# 8126  1396 CC         290000
# 8127  1396 CC         290000
#
# [8128 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.scatter(carDf['engine'].astype(str), carDf['selling_price'])
plt.ylabel('Feature of Selling Price')
plt.xlabel('Feature of Engine')
plt.show()

# %%
carDf[["max_power","selling_price"]]
# Out:
#        max_power  selling_price
# 0         74 bhp         450000
# 1     103.52 bhp         370000
# 2         78 bhp         158000
# 3         90 bhp         225000
# 4       88.2 bhp         130000
# ...          ...            ...
# 8123   82.85 bhp         320000
# 8124     110 bhp         135000
# 8125    73.9 bhp         382000
# 8126      70 bhp         290000
# 8127      70 bhp         290000
#
# [8128 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.scatter(carDf['max_power'].astype(str), carDf['selling_price'])
plt.ylabel('Feature of Selling Price')
plt.xlabel('Feature of Max_power')
plt.show()

# %%
carDf[["seats","selling_price"]]
# Out:
#       seats  selling_price
# 0       5.0         450000
# 1       5.0         370000
# 2       5.0         158000
# 3       5.0         225000
# 4       5.0         130000
# ...     ...            ...
# 8123    5.0         320000
# 8124    5.0         135000
# 8125    5.0         382000
# 8126    5.0         290000
# 8127    5.0         290000
#
# [8128 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.scatter(carDf['seats'].astype(str), carDf['selling_price'])
plt.ylabel('Feature of Selling Price')
plt.xlabel('Feature of Seats')
plt.show()

# %%
#one hot encoding
one_hot_encoded_data = pd.get_dummies(carDf, columns = ['name', 'fuel','owner','transmission','seller_type'])
one_hot_encoded_data
# Out:
#       year  selling_price  km_driven     mileage   engine   max_power  seats  \
# 0     2014         450000     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1     2014         370000     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2     2006         158000     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3     2010         225000     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4     2007         130000     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ...    ...            ...        ...         ...      ...         ...    ...
# 8123  2013         320000     110000   18.5 kmpl  1197 CC   82.85 bhp    5.0
# 8124  2007         135000     119000   16.8 kmpl  1493 CC     110 bhp    5.0
# 8125  2009         382000     120000   19.3 kmpl  1248 CC    73.9 bhp    5.0
# 8126  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
# 8127  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
#
#       name_Ambassador CLASSIC 1500 DSL AC  \
# ...

# %%
#droping missing values
one_hot_encoded_data.dropna(inplace=True)
one_hot_encoded_data
# Out:
#       year  selling_price  km_driven     mileage   engine   max_power  seats  \
# 0     2014         450000     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1     2014         370000     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2     2006         158000     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3     2010         225000     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4     2007         130000     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ...    ...            ...        ...         ...      ...         ...    ...
# 8123  2013         320000     110000   18.5 kmpl  1197 CC   82.85 bhp    5.0
# 8124  2007         135000     119000   16.8 kmpl  1493 CC     110 bhp    5.0
# 8125  2009         382000     120000   19.3 kmpl  1248 CC    73.9 bhp    5.0
# 8126  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
# 8127  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
#
#       name_Ambassador CLASSIC 1500 DSL AC  \
# ...

# %%
one_hot_encoded_data
# Out:
#       year  selling_price  km_driven     mileage   engine   max_power  seats  \
# 0     2014         450000     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1     2014         370000     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2     2006         158000     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3     2010         225000     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4     2007         130000     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ...    ...            ...        ...         ...      ...         ...    ...
# 8123  2013         320000     110000   18.5 kmpl  1197 CC   82.85 bhp    5.0
# 8124  2007         135000     119000   16.8 kmpl  1493 CC     110 bhp    5.0
# 8125  2009         382000     120000   19.3 kmpl  1248 CC    73.9 bhp    5.0
# 8126  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
# 8127  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
#
#       name_Ambassador CLASSIC 1500 DSL AC  \
# ...

# %%
#correlation
one_hot_encoded_data.corr("pearson")
# Out:
#                                          year  selling_price  km_driven  \
# year                                 1.000000       0.412268  -0.428434
# selling_price                        0.412268       1.000000  -0.222196
# km_driven                           -0.428434      -0.222196   1.000000
# seats                               -0.009144       0.041358   0.227336
# name_Ambassador CLASSIC 1500 DSL AC -0.040671      -0.007946   0.004121
# ...                                       ...            ...        ...
# transmission_Automatic               0.248972       0.590279  -0.201207
# transmission_Manual                 -0.248972      -0.590279   0.201207
# seller_type_Dealer                   0.214529       0.401822  -0.178748
# seller_type_Individual              -0.243731      -0.386174   0.202875
# seller_type_Trustmark Dealer         0.100382       0.032794  -0.083191
#
#                                         seats  \
# year                                -0.009144
# ...

# %%
#specify the datas according to the dependent and independent Y is dependent the others are dependentte
Y = one_hot_encoded_data["selling_price"]
one_hot_encoded_data.drop("selling_price",axis=1,inplace=True)
one_hot_encoded_data
# Out:
#       year  km_driven     mileage   engine   max_power  seats  \
# 0     2014     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1     2014     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2     2006     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3     2010     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4     2007     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ...    ...        ...         ...      ...         ...    ...
# 8123  2013     110000   18.5 kmpl  1197 CC   82.85 bhp    5.0
# 8124  2007     119000   16.8 kmpl  1493 CC     110 bhp    5.0
# 8125  2009     120000   19.3 kmpl  1248 CC    73.9 bhp    5.0
# 8126  2013      25000  23.57 kmpl  1396 CC      70 bhp    5.0
# 8127  2013      25000  23.57 kmpl  1396 CC      70 bhp    5.0
#
#       name_Ambassador CLASSIC 1500 DSL AC  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# ...

# %%
one_hot_encoded_data
# Out:
#       year  km_driven     mileage   engine   max_power  seats  \
# 0     2014     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1     2014     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2     2006     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3     2010     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4     2007     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ...    ...        ...         ...      ...         ...    ...
# 8123  2013     110000   18.5 kmpl  1197 CC   82.85 bhp    5.0
# 8124  2007     119000   16.8 kmpl  1493 CC     110 bhp    5.0
# 8125  2009     120000   19.3 kmpl  1248 CC    73.9 bhp    5.0
# 8126  2013      25000  23.57 kmpl  1396 CC      70 bhp    5.0
# 8127  2013      25000  23.57 kmpl  1396 CC      70 bhp    5.0
#
#       name_Ambassador CLASSIC 1500 DSL AC  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# ...

# %%
#independent variables
X = one_hot_encoded_data.copy()
X
# Out:
#       year  km_driven     mileage   engine   max_power  seats  \
# 0     2014     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1     2014     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2     2006     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3     2010     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4     2007     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ...    ...        ...         ...      ...         ...    ...
# 8123  2013     110000   18.5 kmpl  1197 CC   82.85 bhp    5.0
# 8124  2007     119000   16.8 kmpl  1493 CC     110 bhp    5.0
# 8125  2009     120000   19.3 kmpl  1248 CC    73.9 bhp    5.0
# 8126  2013      25000  23.57 kmpl  1396 CC      70 bhp    5.0
# 8127  2013      25000  23.57 kmpl  1396 CC      70 bhp    5.0
#
#       name_Ambassador CLASSIC 1500 DSL AC  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# ...

# %%
#Dependent variable
Y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 7906, dtype: int64

# %%
#Removing unit names 
X['mileage'] = X['mileage'].map(lambda x: x.lstrip('+-').rstrip('kmpl'))
X['engine'] = X['engine'].map(lambda x: x.lstrip('+-').rstrip('CC'))
X['max_power'] = X['max_power'].map(lambda x: x.lstrip('+-').rstrip('bhp'))
X['mileage'] = X['mileage'].map(lambda x: x.lstrip('+-').rstrip('km/kg'))
X
# Out:
#       year  km_driven mileage engine max_power  seats  \
# 0     2014     145500   23.4   1248        74     5.0
# 1     2014     120000  21.14   1498    103.52     5.0
# 2     2006     140000   17.7   1497        78     5.0
# 3     2010     127000   23.0   1396        90     5.0
# 4     2007     120000   16.1   1298      88.2     5.0
# ...    ...        ...     ...    ...       ...    ...
# 8123  2013     110000   18.5   1197     82.85     5.0
# 8124  2007     119000   16.8   1493       110     5.0
# 8125  2009     120000   19.3   1248      73.9     5.0
# 8126  2013      25000  23.57   1396        70     5.0
# 8127  2013      25000  23.57   1396        70     5.0
#
#       name_Ambassador CLASSIC 1500 DSL AC  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# ...

# %%
X.isnull().sum()
# Out:
# year                            0
# km_driven                       0
# mileage                         0
# engine                          0
# max_power                       0
#                                ..
# transmission_Automatic          0
# transmission_Manual             0
# seller_type_Dealer              0
# seller_type_Individual          0
# seller_type_Trustmark Dealer    0
# Length: 2078, dtype: int64

# %%
#converting year to age
X["year"] = 2021 - X["year"]
X
# Out:
#       year  km_driven mileage engine max_power  seats  \
# 0        7     145500   23.4   1248        74     5.0
# 1        7     120000  21.14   1498    103.52     5.0
# 2       15     140000   17.7   1497        78     5.0
# 3       11     127000   23.0   1396        90     5.0
# 4       14     120000   16.1   1298      88.2     5.0
# ...    ...        ...     ...    ...       ...    ...
# 8123     8     110000   18.5   1197     82.85     5.0
# 8124    14     119000   16.8   1493       110     5.0
# 8125    12     120000   19.3   1248      73.9     5.0
# 8126     8      25000  23.57   1396        70     5.0
# 8127     8      25000  23.57   1396        70     5.0
#
#       name_Ambassador CLASSIC 1500 DSL AC  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# ...

# %%
#removing 4933 item from the data frame because of empty string
X = X.drop(labels=4933, axis=0)

# %%
Y = Y.drop(labels=4933, axis=0)

# %%
#splitting data as train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(X,Y, test_size=0.2, random_state=147)

# %%
#transform the data between range(0,1)
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1)) 
scaled_x_train=scaler.fit_transform(x_train)
scaled_x_train
# Out:
# array([[0.26923077, 0.03600957, 0.39404762, ..., 0.        , 1.        ,
#         0.        ],
#        [0.26923077, 0.03473863, 0.63309524, ..., 1.        , 0.        ,
#         0.        ],
#        [0.03846154, 0.0023809 , 0.52380952, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.15384615, 0.00423605, 0.59928571, ..., 0.        , 1.        ,
#         0.        ],
#        [0.19230769, 0.10167485, 0.47571429, ..., 0.        , 1.        ,
#         0.        ],
#        [0.34615385, 0.02118192, 0.36595238, ..., 0.        , 1.        ,
#         0.        ]])

# %%
#linear regression
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(scaled_x_train,y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
#calculating model coefficient
model.coef_
# Out:
# array([-9.00488385e+05, -4.35154169e+05,  1.21057314e+05, ...,
#        -1.41175470e+14, -1.41175470e+14, -1.41175470e+14])

# %%
#calculate the model intercept
model.intercept_
# Out:
# 9427812788718560.0

# %%
#printin the formula
_str="y="

for i, m in enumerate(model.coef_):
    _str+="x_{}*{}+".format(i,m)
_str+=str(model.intercept_)


print(_str)
# Out:
# y=x_0*-900488.3854311038+x_1*-435154.1689005598+x_2*121057.31382656796+x_3*816454.7907585775+x_4*3456056.910683213+x_5*-839533.5169968742+x_6*-168779965090147.56+x_7*-168779965151804.75+x_8*-168779965619568.75+x_9*-168779965533901.9+x_10*-168779965470301.47+x_11*-1423555930438309.2+x_12*-2.2472552951587148e+16+x_13*-1.0962610682375722e+16+x_14*-1423555931517260.2+x_15*-1423555932156030.2+x_16*-1423555931376963.5+x_17*-1423555931201627.5+x_18*-1423555931821214.2+x_19*-1423555931340278.0+x_20*-1423555931604751.5+x_21*-1.2812447505635904e+16+x_22*-1423555931323680.2+x_23*-1423555930754605.0+x_24*-1423555931370806.5+x_25*-1423555931909032.8+x_26*-1423555932440516.2+x_27*-1423555929710833.2+x_28*-6.3663667894918984e+16+x_29*-1423555932347648.2+x_30*-1423555932229033.5+x_31*1.3290485083437734e+16+x_32*-2.9125967010295056e+16+x_33*-1423555932518931.5+x_34*-1423555930712480.0+x_35*-1423555932212695.0+x_36*-1423555931854228.8+x_37*-1423555931091614.8+x_38*-1423555932122551.5+x_39*-14235559318
# ...

# %%
#tranforming the test data range between 0 and 1
scaled_x_test=scaler.fit_transform(x_test)

# %%
#predicting
y_predict=model.predict(scaled_x_test)

# %%
y_predict
# Out:
# array([ 1.68779966e+14,  3.06504000e+05, -7.81432707e+14, ...,
#         3.09744000e+06,  7.17864000e+05,  8.42774000e+05])

# %%
df_y_test = y_test.to_numpy()
df_y_test
# Out:
# array([ 500000,   65000,  270000, ..., 2475000,  450000,  390000])

# %%
#print the predicted and actual values of the data in the test set

for i in range(len(y_predict)):
    print("Predicted value:", y_predict[i]," Actual value:",y_test.values[i])
# Out:
# Predicted value: 168779966329048.0  Actual value: 500000
# Predicted value: 306504.0  Actual value: 65000
# Predicted value: -781432707327728.0  Actual value: 270000
# Predicted value: 239992.0  Actual value: 500000
# Predicted value: 386024.0  Actual value: 250999
# Predicted value: 385624.0  Actual value: 340000
# Predicted value: 637478.0  Actual value: 320000
# Predicted value: 690038.0  Actual value: 425000
# Predicted value: 608700.0  Actual value: 520000
# Predicted value: 847082.0  Actual value: 395000
# Predicted value: 897402.0  Actual value: 700000
# Predicted value: 1678930.0  Actual value: 1150000
# Predicted value: 680870.0  Actual value: 434999
# Predicted value: -68888.0  Actual value: 54000
# Predicted value: 929266.0  Actual value: 630000
# Predicted value: 707870.0  Actual value: 450000
# Predicted value: 470836.0  Actual value: 400000
# Predicted value: 286810.0  Actual value: 190000
# Predicted value: 4028838.0  Actual value: 3790000
# ...

# %%
#mean squared error calculation
MSE = np.square(np.subtract(y_test,y_predict)).mean()
MSE
# Out:
# 6.893523388663359e+31

# %%
#mean absolute error calculation
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_predict)
# Out:
# 993276743210525.6

# %%
#Root-mean-squared error calculation
import math
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 8302724485771739.0

# %%
#f2 score calculation
from sklearn.metrics import r2_score
r2_score(y_test, y_predict)
# Out:
# -1.2624132971257396e+20

# %%
#difference between true and prediction values calculation
difference = np.subtract(df_y_test,y_predict)
difference
# Out:
# array([-1.68779966e+14, -2.41504000e+05,  7.81432708e+14, ...,
#        -6.22440000e+05, -2.67864000e+05, -4.52774000e+05])

# %%
#visualizing the difference
import matplotlib.pyplot as plt
plt.plot(difference)
plt.show()

# %%
#calculation of score
model.score(scaled_x_train,y_train)
# Out:
# 0.9888487533180439

# %%
y_test.shape
score=model.score(scaled_x_test, y_test)
score
# Out:
# -1.2624132971257396e+20

# %%
#implementing of randomforestregressor
from sklearn.ensemble import RandomForestRegressor
myforest=RandomForestRegressor(n_estimators=100, random_state=0)
myforest.fit(scaled_x_train,y_train)
myforest.predict(scaled_x_test)
score=myforest.score(scaled_x_test, y_test)
score
# Out:
# 0.43212481741190656

# %%
#calculation of prediction
y_predict_forest=myforest.predict(scaled_x_test)

# %%
y_predict_forest
# Out:
# array([ 379819.94      ,  213449.99      ,  308109.98      , ...,
#        3984195.14024765,  363989.99      ,  941840.        ])

# %%
#print the predicted and actual values of the data in the test set
for i in range(len(y_predict)):
    print("Predicted value:", y_predict_forest[i]," Actual value:",y_test.values[i])
# Out:
# Predicted value: 379819.94  Actual value: 500000
# Predicted value: 213449.99  Actual value: 65000
# Predicted value: 308109.98  Actual value: 270000
# Predicted value: 415409.98  Actual value: 500000
# Predicted value: 315409.96  Actual value: 250999
# Predicted value: 314569.97  Actual value: 340000
# Predicted value: 541897.47  Actual value: 320000
# Predicted value: 587659.97  Actual value: 425000
# Predicted value: 1150839.99  Actual value: 520000
# Predicted value: 473369.98  Actual value: 395000
# Predicted value: 622149.99  Actual value: 700000
# Predicted value: 1813780.0  Actual value: 1150000
# Predicted value: 602059.99  Actual value: 434999
# Predicted value: 113873.24333333335  Actual value: 54000
# Predicted value: 693849.98  Actual value: 630000
# Predicted value: 623689.93  Actual value: 450000
# Predicted value: 428409.96  Actual value: 400000
# Predicted value: 135069.97  Actual value: 190000
# Predicted value: 6320800.0  Actual value: 3790000
# ...

# %%
#calculation of mean squared error
MSE = np.square(np.subtract(y_test,y_predict_forest)).mean()
MSE
# Out:
# 310093442609.1185

# %%
#calculation of mean absolute error
mean_absolute_error(y_test, y_predict_forest)
# Out:
# 276524.0135090737

# %%
#Root-mean-squared error
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 556860.3439006215

# %%
#calculation of r2 score
r2_score(y_test, y_predict_forest)
# Out:
# 0.43212481741190656

# %%
#difference between true and prediction values calculation
difference = np.subtract(df_y_test,y_predict_forest)
difference
# Out:
# array([  120180.06      ,  -148449.99      ,   -38109.98      , ...,
#        -1509195.14024765,    86010.01      ,  -551840.        ])

# %%
#visualizing the difference
plt.plot(difference)
plt.show()
